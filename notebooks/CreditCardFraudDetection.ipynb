# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sunnysavita10/credit_card_pw_hindi/main/creditCardFraud_28011964_120214.csv')

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
# ...

# %%
df.describe()
# Out:
#            LIMIT_BAL          SEX    EDUCATION     MARRIAGE          AGE  \
# count    1001.000000  1001.000000  1001.000000  1001.000000  1001.000000
# mean   167532.467532     1.589411     1.776224     1.604396    34.945055
# std    130587.921320     0.492187     0.750916     0.532298     9.219760
# min     10000.000000     1.000000     1.000000     0.000000    21.000000
# 25%     50000.000000     1.000000     1.000000     1.000000    28.000000
# 50%    140000.000000     2.000000     2.000000     2.000000    33.000000
# 75%    240000.000000     2.000000     2.000000     2.000000    41.000000
# max    700000.000000     2.000000     6.000000     3.000000    75.000000
#
#              PAY_0        PAY_2        PAY_3        PAY_4        PAY_5  ...  \
# count  1001.000000  1001.000000  1001.000000  1001.000000  1001.000000  ...
# mean     -0.004995    -0.161838    -0.164835    -0.283716    -0.283716  ...
# std       1.173446     1.228732     1.262459     1.184662     1.170224  ...
# ...

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df['SEX'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6], dtype=int64)

# %%
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 2    447
# 1    396
# 3    151
# 5      3
# 4      2
# 6      2
# Name: count, dtype: int64

# %%
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    570
# 1    409
# 3     19
# 0      3
# Name: count, dtype: int64

# %%
df['PAY_0'].unique()
# Out:
# array([-1,  0, -2,  1,  2,  3,  4,  8], dtype=int64)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
X=df.drop(labels=["default payment next month"],axis=1)

# %%
X
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
# ...

# %%
y = df["default payment next month"]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
#Segreating numerical and categorical variables
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
from sklearn.impute import SimpleImputer  #Missing values
from sklearn.preprocessing import StandardScaler #Handling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder #ordinal Encoding

#Pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
#Numerical Pipelines
num_pipeline = Pipeline(
    steps =[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler',StandardScaler())
    ]
)

# %%
preprocessor = ColumnTransformer([
    ('num_pipeline',num_pipeline,numerical_cols),
])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((700, 23), (301, 23))

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.9)
len(set(corr_features))
# Out:
# 5

# %%
corr_features
# Out:
# {'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 708     360000    2          1         1   30      1      2     -1      0
# 533     120000    1          2         1   44      0      0      0      0
# 298      50000    2          3         1   40      0      0      0      0
# 356     500000    2          2         2   23      4      3      2      0
# 833     110000    2          2         1   55      0      0      0      0
# ..         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 889     320000    1          1         2   27      0      0      0      0
# 474     500000    2          1         1   38     -1      2     -1     -1
# 416      30000    1          1         2   24      2      0      0      0
# 10      250000    1          1         2   29      0      0      0      0
# 105     360000    1          2         1   35      1     -2     -2     -2
#
#      PAY_5  PAY_6  BILL_AMT1  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 X_train.columns()
#
# TypeError: 'Index' object is not callable

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train.head()
# Out:
#    num_pipeline__LIMIT_BAL  num_pipeline__SEX  num_pipeline__EDUCATION  \
# 0                 0.258606           0.818929                 0.251548
# 1                 0.181047          -1.221107                 0.251548
# 2                 1.499562           0.818929                 0.251548
# 3                -0.904790          -1.221107                 0.251548
# 4                -0.051633           0.818929                -1.043186
#
#    num_pipeline__MARRIAGE  num_pipeline__AGE  num_pipeline__PAY_0  \
# 0               -1.159683          -0.309380            -0.825651
# 1               -1.159683          -0.418922             0.013182
# 2               -1.159683           0.238333             0.852014
# 3                0.715093          -1.295263            -0.825651
# 4               -1.159683           0.347876            -0.825651
#
#    num_pipeline__PAY_2  num_pipeline__PAY_3  num_pipeline__PAY_4  \
# 0            -0.665272            -0.662476            -0.596168
# ...

# %%
#  Model Training
from sklearn.naive_bayes  import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, fbeta_score
from sklearn.model_selection import GridSearchCV

# %%
import numpy as np
def evaluate_model(true,predicated):
    accuracy = accuracy_score(true,predicated)
    recall = recall_score(true, predicated)
    precision = precision_score(true,predicated)
    fbeta = fbeta_score(true, predicated, beta=1)
    return accuracy,recall,precision,fbeta

# %%
## Train multiple models
## Model Evaluations
models = {
    'GaussianNB' :GaussianNB(),
    'XGBoost' : GradientBoostingClassifier(),
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': LogisticRegression(),
    'SupportVector': SVC()
}
# for gridsearch cv
param_grid = {
    'GaussianNB': {},
    'XGBoost': {'learning_rate': [0.01, 0.1], 'n_estimators': [100, 500]},
    'RandomForest': {'n_estimators': [100, 500], 'max_depth': [None, 5, 10]},
    'LogisticRegression': {'C': [0.1, 1, 10]},
    'SupportVector': {'C': [0.1, 1, 10], 'kernel': ['linear', 'rbf']}
}

trained_model_list = []
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #for grid search cv
    model_name = list(models.keys())[i]
    
    grid_search = GridSearchCV(model, param_grid[model_name], cv=5)
    grid_search.fit(X_train, y_train)
    
    best_model = grid_search.best_estimator_    

    #Make Predictions
    y_pred=model.predict(X_test)
    
    ### if need to apply gridsearch cv use below code
    # y_pred = best_model.predict(X_test)

    accuracy, recall, precision,fbeta=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("Accuracy score:",accuracy*100)
    print("Recall score:",recall*100)
    print("Precision score:",precision*100)
    print("Fbeta_score :",fbeta*100)

    r2_list.append(accuracy)
    
    print('='*35)
    print('\n')
# Out:
# GaussianNB
# Model Training Performance
# Accuracy score: 39.202657807308974
# Recall score: 76.19047619047619
# Precision score: 22.22222222222222
# Fbeta_score : 34.40860215053764
# ...
#
#
# XGBoost
# Model Training Performance
# Accuracy score: 80.06644518272425
# Recall score: 34.92063492063492
# Precision score: 53.65853658536586
# Fbeta_score : 42.30769230769231
# ...
#
#
# RandomForest
# Model Training Performance
# Accuracy score: 79.40199335548172
# Recall score: 25.396825396825395
# Precision score: 51.61290322580645
# Fbeta_score : 34.04255319148936
# ...
#
#
# LogisticRegression
# Model Training Performance
# Accuracy score: 79.40199335548172
# Recall score: 7.936507936507936
# Precision score: 55.55555555555556
# Fbeta_score : 13.88888888888889
# ...
#
#
# SupportVector
# Model Training Performance
# Accuracy score: 78.7375415282392
# Recall score: 4.761904761904762
# Precision score: 42.857142857142854
# Fbeta_score : 8.571428571428571
# ...

# %%
model_list
# Out:
# ['GaussianNB',
#  'XGBoost',
#  'RandomForest',
#  'LogisticRegression',
#  'SupportVector']
